# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.tree import plot_tree

# %%
X, y = make_classification(n_features=5, n_informative=1, n_redundant=0, n_clusters_per_class=1)

# %%
df = pd.DataFrame(X, columns=["col1", "col2", "col3", "col4", "col5"])
df["target"] = y
df
# Out:
#         col1      col2      col3      col4      col5  target
# 0  -0.579991 -0.525084 -0.575451  1.006464  0.287223       1
# 1   1.135827  0.046514  0.169550  0.936222  0.147214       1
# 2  -0.323928  1.356020  0.600038 -0.922904  0.709178       0
# 3  -0.416234  2.387221 -0.614313 -0.973517 -1.692752       0
# 4   1.289243  0.477769 -1.262894  1.114093  0.580031       1
# ..       ...       ...       ...       ...       ...     ...
# 95  0.975081  0.752874  0.414771 -1.065130  0.662819       0
# 96 -1.742610  0.140792 -1.002296 -0.964699 -1.442529       0
# 97  1.081199 -0.033675 -1.468432 -1.030717 -0.596853       0
# 98  0.034385  0.039342  1.060861  1.103582 -0.171579       1
# 99  0.655974 -0.745799 -0.328088  1.094645  1.389849       1
#
# [100 rows x 6 columns]

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:, :5], df.iloc[:, -1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12, 12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rafc = RandomForestClassifier(max_features=2)

# %%
rafc.fit(df.iloc[:, :5], df.iloc[:, -1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12, 12))
plot_tree(rafc.estimators_[6])
plt.show()

# %% [markdown]
# #### As we can see from the two trees above, the first one is made from BaggingClassifier and in this algorithms, every node is determined from either of the one rows that we've chosen earlier. Therefore, there is node level sampling
